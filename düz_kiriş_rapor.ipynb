# %% [markdown]
# ## Experimental Düz kirişler raporu
# # 1. ankastre kiriş eğilmesi
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# deflection bu şekilde verilmiştir

# %% [markdown]
# kütüphanelerin çağıralım
# değişkenleri atayalım
# bizim 20mm eni 6mm boyu vardı
# Elastic modulusu E=97e3 (N/mm^2)
# L değişken L_1=400mm L_2=500mm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
E=E=97e3 #(N/mm^2) elastic modulus
I_y=1/(12*20*6**3) # (mm^4) moment of inertia

# %%
#1.experiment
uzunluk=["L_1","L_2"]
kuvvet=["2.5N","7.5N","10N"]
veri=[[abs(14.61-13.51),abs(13.51-10.50),abs(10.50-9)],[abs(9.68-4.12),abs(4.12-1.41),abs(1.41-11.95)]]
data_frame_1=pd.DataFrame(veri,columns=kuvvet,index=uzunluk)
L_1=400 # (mm) length of the 1.1 experiment
L_2=500 # (mm) length of the 1.2 experiment
data_frame_1
# Out:
#      2.5N  7.5N    10N
# L_1  1.10  3.01   1.50
# L_2  5.56  2.71  10.54
